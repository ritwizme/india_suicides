# %%
import pandas as pd

# %%
df = pd.read_csv("sus.csv")

# %%
df
# Out:
#                 State  Year             Type_code  \
# 0       A & N Islands  2001                Causes
# 1       A & N Islands  2001                Causes
# 2       A & N Islands  2001                Causes
# 3       A & N Islands  2001                Causes
# 4       A & N Islands  2001                Causes
# 5       A & N Islands  2001                Causes
# 6       A & N Islands  2001                Causes
# 7       A & N Islands  2001                Causes
# 8       A & N Islands  2001                Causes
# 9       A & N Islands  2001                Causes
# 10      A & N Islands  2001                Causes
# 11      A & N Islands  2001                Causes
# 12      A & N Islands  2001                Causes
# 13      A & N Islands  2001                Causes
# 14      A & N Islands  2001                Causes
# 15      A & N Islands  2001                Causes
# 16      A & N Islands  2001                Causes
# 17      A & N Islands  2001                Causes
# 18      A & N Islands  2001                Causes
# 19      A & N Islands  2001                Causes
# 20      A & N Islands  2001                Causes
# 21      A & N Islands  2001                Causes
# 22      A & N Islands  2001                Causes
# 23      A & N Islands  2001                Causes
# 24      A & N Islands  2001                Causes
# 25      A & N Islands  2001                Causes
# 26      A & N Islands  2001                Causes
# 27      A & N Islands  2001                Causes
# 28      A & N Islands  2001                Causes
# 29      A & N Islands  2001                Causes
# ...               ...   ...                   ...
# 237489    West Bengal  2012  Professional_Profile
# 237490    West Bengal  2012  Professional_Profile
# 237491    West Bengal  2012  Professional_Profile
# 237492    West Bengal  2012  Professional_Profile
# 237493    West Bengal  2012  Professional_Profile
# 237494    West Bengal  2012  Professional_Profile
# 237495    West Bengal  2012  Professional_Profile
# 237496    West Bengal  2012  Professional_Profile
# 237497    West Bengal  2012  Professional_Profile
# 237498    West Bengal  2012  Professional_Profile
# 237499    West Bengal  2012  Professional_Profile
# 237500    West Bengal  2012  Professional_Profile
# 237501    West Bengal  2012  Professional_Profile
# 237502    West Bengal  2012  Professional_Profile
# 237503    West Bengal  2012  Professional_Profile
# 237504    West Bengal  2012  Professional_Profile
# 237505    West Bengal  2012  Professional_Profile
# 237506    West Bengal  2012  Professional_Profile
# 237507    West Bengal  2012  Professional_Profile
# 237508    West Bengal  2012  Professional_Profile
# 237509    West Bengal  2012         Social_Status
# 237510    West Bengal  2012         Social_Status
# 237511    West Bengal  2012         Social_Status
# 237512    West Bengal  2012         Social_Status
# 237513    West Bengal  2012         Social_Status
# 237514    West Bengal  2012         Social_Status
# 237515    West Bengal  2012         Social_Status
# 237516    West Bengal  2012         Social_Status
# 237517    West Bengal  2012         Social_Status
# 237518    West Bengal  2012         Social_Status
#
#                                             Type  Gender Age_group  Total
# 0                             Illness (Aids/STD)  Female      0-14      0
# 1        Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2        Cancellation/Non-Settlement of Marriage  Female      0-14      0
#
# 237518                             Never Married    Male    0-100+   2658
#
# [237519 rows x 7 columns]

# %%
df = df[df.Year == 2001]

# %%
df.head()
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# 4  Female      0-14      0

# %%
df = df[df.Type == "Never Married"][df.State=="A & N Islands"]

# %%
df
# Out:
#               State  Year      Type_code           Type Gender Age_group  \
# 560   A & N Islands  2001  Social_Status  Never Married   Male    0-100+
# 1115  A & N Islands  2002  Social_Status  Never Married   Male    0-100+
# 1671  A & N Islands  2003  Social_Status  Never Married   Male    0-100+
# 2234  A & N Islands  2004  Social_Status  Never Married   Male    0-100+
# 2791  A & N Islands  2005  Social_Status  Never Married   Male    0-100+
# 3351  A & N Islands  2006  Social_Status  Never Married   Male    0-100+
# 3907  A & N Islands  2007  Social_Status  Never Married   Male    0-100+
# 4470  A & N Islands  2008  Social_Status  Never Married   Male    0-100+
# 5030  A & N Islands  2009  Social_Status  Never Married   Male    0-100+
# 5589  A & N Islands  2010  Social_Status  Never Married   Male    0-100+
# 6151  A & N Islands  2011  Social_Status  Never Married   Male    0-100+
# 6709  A & N Islands  2012  Social_Status  Never Married   Male    0-100+
#
#       Total
# 560      24
# 1115     37
# 1671     19
# 2234     23
# 2791     25
# 3351     47
# 3907     45
# 4470     27
# 5030     20
# 5589     42
# 6151     20
# 6709     28

# %%
import matplotlib.pyplot as plt 
import numpy as np
X = df.iloc[:,[1]].values
y = df.iloc[:,[6]].values
plt.plot(X,y)
plt.show()

# %%
from sklearn.tree as DecisionTreeRegressor
# Out:
#   File "<ipython-input-21-9c3bf2278f0b>", line 1
#     from sklearn.tree as DecisionTreeRegressor
#                        ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators=200,random_state=0)

# %%
regressor.fit(X,y)
# Out:
# C:\Users\keshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
regressor.predict(2018)
# Out:
# array([27.09])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report,confusion_matrix

# %%
regressor = RandomForestRegressor(n_estimators=200,random_state=0)

# %%
regressor.fit(X_train,y_train)
# Out:
# C:\Users\keshu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pred = regressor.predict(X_test)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-c35a386f755a> in <module>()
# ----> 1 print(confusion_matrix(y_test,pred))
#
# NameError: name 'confusion_matrix' is not defined
